# %% [markdown]
# <h1>5.2 案例二：淘宝 APP 消费者行为分析</h1>

# %% [markdown]
# <div><span style="font-size: 12pt; font-family: TimesNewRomanPS-BoldMT;">5.2.1 </span><span style="font-size: 12pt; font-family: 楷体;">项目背景 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">用户在网上购物会产生一系列的行为，这些行为包括点击、收藏、加购物车、购买 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">商品等。对于一个公司来说，分析这些行为数据，了解消费者互联网使用习惯及购买行 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">为，有利于销售量提升，创造更多价值。 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">对于这类行为数据，常见的分析包括： </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">关键指标统计，如 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">PV</span><span style="font-size: 12pt; font-family: 宋体;">、商品、消费者等统计分析； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">销售漏斗分析，即&ldquo;浏览数&mdash;收藏或加购物车数&mdash;购买数&rdquo;漏斗模型； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 'Times New Roman';">RFM </span><span style="font-size: 12pt; font-family: 宋体;">分析，即根据&ldquo;最近一次消费（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">Recency</span><span style="font-size: 12pt; font-family: 宋体;">）、消费频率（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">Frequency</span><span style="font-size: 12pt; font-family: 宋体;">）、消费 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">金额（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">Monetary</span><span style="font-size: 12pt; font-family: 宋体;">）&rdquo;对消费者进行分类。 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">数据来源于淘宝 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">APP</span><span style="font-size: 12pt; font-family: 宋体;">，由&ldquo;天池新人实战赛之</span><span style="font-size: 12pt; font-family: 'Times New Roman';">[</span><span style="font-size: 12pt; font-family: 宋体;">离线赛</span><span style="font-size: 12pt; font-family: 'Times New Roman';">]</span><span style="font-size: 12pt; font-family: 宋体;">&rdquo;（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">https://tianchi.aliyun.com </span></div>
# <div><span style="font-size: 12pt; font-family: 'Times New Roman';">/competition /entrance/231522/information</span><span style="font-size: 12pt; font-family: 宋体;">）提供，数据文件名为&ldquo;</span><span style="font-size: 12pt; font-family: 'Times New Roman';">tianchi_fresh_comp_ </span></div>
# <div><span style="font-size: 12pt; font-family: 'Times New Roman';">train_user.csv</span><span style="font-size: 12pt; font-family: 宋体;">&rdquo;，内含 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">20000 </span><span style="font-size: 12pt; font-family: 宋体;">用户在一个月时间（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">2014.11.18-12.18</span><span style="font-size: 12pt; font-family: 宋体;">）之内的移动端行为 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">数据。 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">数据文件的字段说明如表 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">5.1 </span><span style="font-size: 12pt; font-family: 宋体;">所示。</span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;"><img src="data:image/png;base64,..." alt="" /></span></div>

# %% [markdown]
# ... 中间略，心累

# %% [markdown]
# <div><span style="font-size: 12pt; font-family: TimesNewRomanPS-BoldMT;">5.2.6 </span><span style="font-size: 12pt; font-family: 楷体;">结论与建议 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">1</span><span style="font-size: 12pt; font-family: 宋体;">）主要发现 </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 'Times New Roman';">20000 </span><span style="font-size: 12pt; font-family: 宋体;">万名消费者中，每天约 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">6 </span><span style="font-size: 12pt; font-family: 宋体;">成消费者登录淘宝 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">APP</span><span style="font-size: 12pt; font-family: 宋体;">，每次人均访问 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">35 </span><span style="font-size: 12pt; font-family: 宋体;">个商 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">品，累计访问商品 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">4,758,484 </span><span style="font-size: 12pt; font-family: 宋体;">个； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">每晚 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">7 </span><span style="font-size: 12pt; font-family: 宋体;">点至 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">11 </span><span style="font-size: 12pt; font-family: 宋体;">点是消费者选购商品的高峰时间，凌晨至早上 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">8 </span><span style="font-size: 12pt; font-family: 宋体;">点人数最少，白天 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">趋于平稳状态；</span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">缺乏爆款商品，销量最大的商品也仅 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">46 </span><span style="font-size: 12pt; font-family: 宋体;">件，产生销量商品的有 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">170451 </span><span style="font-size: 12pt; font-family: 宋体;">个，占总 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">数的 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">3.58%</span><span style="font-size: 12pt; font-family: 宋体;">，绝大部分商品没有销售； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">浏览的商品中，有 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">6.63%</span><span style="font-size: 12pt; font-family: 宋体;">的收藏或加购物车，而购买地占比为 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">1.41%</span><span style="font-size: 12pt; font-family: 宋体;">； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">消费者中，</span><span style="font-size: 12pt; font-family: 'Times New Roman';">1 </span><span style="font-size: 12pt; font-family: 宋体;">类 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">3703 </span><span style="font-size: 12pt; font-family: 宋体;">名，</span><span style="font-size: 12pt; font-family: 'Times New Roman';">2 </span><span style="font-size: 12pt; font-family: 宋体;">类 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">849 </span><span style="font-size: 12pt; font-family: 宋体;">名，</span><span style="font-size: 12pt; font-family: 'Times New Roman';">3 </span><span style="font-size: 12pt; font-family: 宋体;">类 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">2 </span><span style="font-size: 12pt; font-family: 宋体;">名，</span><span style="font-size: 12pt; font-family: 'Times New Roman';">4 </span><span style="font-size: 12pt; font-family: 宋体;">类 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">15052 </span><span style="font-size: 12pt; font-family: 宋体;">名，其余为 </span><span style="font-size: 12pt; font-family: 'Times New Roman';">8 </span><span style="font-size: 12pt; font-family: 宋体;">类。 </span></div>
# <div><span style="font-size: 12pt; font-family: 宋体;">（</span><span style="font-size: 12pt; font-family: 'Times New Roman';">2</span><span style="font-size: 12pt; font-family: 宋体;">）对策建议 </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">进一步优化选品，提供消费者需要的好商品； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">引入个性化推荐算法，做好商品推荐工作； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">加大夜市推广活动，增加网店夜间工作人数； </span></div>
# <div><span style="font-size: 12pt;"> </span><span style="font-size: 12pt; font-family: 宋体;">分类管理客户，指定有针对性地营销策略。</span></div>
