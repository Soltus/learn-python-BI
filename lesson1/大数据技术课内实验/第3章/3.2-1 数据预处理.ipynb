# %%
import numpy as np
import pandas as pd

# %%
## 使用read_table读取菜品订单信息表,sep = ','
order2 = pd.read_table('./data/meal_order_info.csv', sep = ',',encoding = 'gbk')
order2
# Out:
#      info_id  emp_id  number_consumers  mode  dining_table_id  \
# 0        417    1442                 4   NaN             1501
# 1        301    1095                 3   NaN             1430
# 2        413    1147                 6   NaN             1488
# 3        415    1166                 4   NaN             1502
# 4        392    1094                10   NaN             1499
# ..       ...     ...               ...   ...              ...
# 940      641    1095                 8   NaN             1492
# 941      672    1089                 6   NaN             1489
# 942      692    1155                 8   NaN             1492
# 943      647    1094                 4   NaN             1485
# 944      570    1113                 8   NaN             1517
#
#      dining_table_name  expenditure  dishes_count  accounts_payable  \
# 0                 1022          165             5               165
# 1                 1031          321             6               321
# ...

# %%
## 使用read_csv读取菜品订单信息表,header=None
order3 = pd.read_csv('./data/meal_order_info.csv', sep = ',',header = None,encoding = 'gbk')
order3
# Out:
#           0       1                 2     3                4   \
# 0    info_id  emp_id  number_consumers  mode  dining_table_id
# 1        417    1442                 4   NaN             1501
# 2        301    1095                 3   NaN             1430
# 3        413    1147                 6   NaN             1488
# 4        415    1166                 4   NaN             1502
# ..       ...     ...               ...   ...              ...
# 941      641    1095                 8   NaN             1492
# 942      672    1089                 6   NaN             1489
# 943      692    1155                 8   NaN             1492
# 944      647    1094                 4   NaN             1485
# 945      570    1113                 8   NaN             1517
#
#                     5            6             7                 8   \
# 0    dining_table_name  expenditure  dishes_count  accounts_payable
# 1                 1022          165             5               165
# ...

# %%
## 使用gbk解析菜品订单信息表
order4 = pd.read_csv('./data/meal_order_info.csv', sep = ',',encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-722e1164f7c4> in <module>
#       1 ## 使用gbk解析菜品订单信息表
# ----> 2 order4 = pd.read_csv('./data/meal_order_info.csv', sep = ',',encoding = 'utf-8')
#
# ...

# %%
## 将order以csv格式存储
order3.to_csv('./data/orderInfo.csv',sep = ';',index = False)

# %%
user = pd.read_excel('./data/users.xlsx')## 读取user.xlsx文件
print('客户信息表长度为：',len(user))
# Out:
# 客户信息表长度为： 734

# %%
#客户信息表写入excel文件前目录内文件列表为：
user.to_excel('./data/userInfo.xlsx')

# %%
dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df2=pd.DataFrame({'A': 1.,'B': pd.Timestamp('20130102'),'C': pd.Series(1, index=list(range(4)), dtype = 'float32'), 'D': np.array([3] * 4, dtype='int32'), 'E': pd.Categorical(["t1", "t2", "t3", "t4"]),'F': 'foo'})

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.161515  0.012649 -0.258957 -1.340256
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714
# 2013-01-04 -0.806553  1.251323  1.635073  0.042678
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077
# 2013-01-06  1.789882  0.732778 -0.935361 -0.737313

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  1.161515  0.012649 -0.258957 -1.340256
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714
# 2013-01-04 -0.806553  1.251323  1.635073  0.042678
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.806553  1.251323  1.635073  0.042678
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077
# 2013-01-06  1.789882  0.732778 -0.935361 -0.737313

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df['A']  #与 df.A 等效
# Out:
# 2013-01-01    1.161515
# 2013-01-02   -1.006992
# 2013-01-03    0.526889
# 2013-01-04   -0.806553
# 2013-01-05    0.777844
# 2013-01-06    1.789882
# Freq: D, Name: A, dtype: float64

# %%
df[['A','C']]
# Out:
#                    A         C
# 2013-01-01  1.161515 -0.258957
# 2013-01-02 -1.006992 -0.880813
# 2013-01-03  0.526889  0.370054
# 2013-01-04 -0.806553  1.635073
# 2013-01-05  0.777844  0.005510
# 2013-01-06  1.789882 -0.935361

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.012649 -0.258957
# 2013-01-02 -0.097120 -0.880813
# 2013-01-03 -1.235301  0.370054
# 2013-01-04  1.251323  1.635073
# 2013-01-05 -1.018387  0.005510
# 2013-01-06  0.732778 -0.935361

# %%
df[:2]
# Out:
#                    A         B         C         D
# 2013-01-01  1.161515  0.012649 -0.258957 -1.340256
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181

# %%
df[2:]
# Out:
#                    A         B         C         D
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714
# 2013-01-04 -0.806553  1.251323  1.635073  0.042678
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077
# 2013-01-06  1.789882  0.732778 -0.935361 -0.737313

# %%
df[1:3]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714

# %%
df['2013-01-02':'2013-01-03']
# Out:
#                    A         B         C         D
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714

# %%
df.loc[dates[2]]   #若未指定Index，为：df.loc[2]；也可按位置选择：df.iloc[2]
# Out:
# A    0.526889
# B   -1.235301
# C    0.370054
# D    1.875714
# Name: 2013-01-03 00:00:00, dtype: float64

# %%
df.iloc[3:5, 1:3]
# Out:
#                    B         C
# 2013-01-04  1.251323  1.635073
# 2013-01-05 -1.018387  0.005510

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02 -1.006992 -0.097120
# 2013-01-03  0.526889 -1.235301
# 2013-01-04 -0.806553  1.251323

# %%
df.iloc[1, 1]
# Out:
# -0.09711956868034481

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.161515  0.012649 -0.258957 -1.340256
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077
# 2013-01-06  1.789882  0.732778 -0.935361 -0.737313

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.161515  0.012649       NaN       NaN
# 2013-01-02       NaN       NaN       NaN  0.540181
# 2013-01-03  0.526889       NaN  0.370054  1.875714
# 2013-01-04       NaN  1.251323  1.635073  0.042678
# 2013-01-05  0.777844       NaN  0.005510  0.164077
# 2013-01-06  1.789882  0.732778       NaN       NaN

# %%
df2[df2['E'].isin(['t1', 't3'])]
# Out:
#      A          B    C  D   E    F
# 0  1.0 2013-01-02  1.0  3  t1  foo
# 2  1.0 2013-01-02  1.0  3  t3  foo

# %%
#按标签赋值
df.at[dates[0], 'A'] = 0 
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000  0.012649 -0.258957 -1.340256
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714
# 2013-01-04 -0.806553  1.251323  1.635073  0.042678
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077
# 2013-01-06  1.789882  0.732778 -0.935361 -0.737313

# %%
#按位置赋值
df.iat[0, 3] = 0
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000  0.012649 -0.258957  0.000000
# 2013-01-02 -1.006992 -0.097120 -0.880813  0.540181
# 2013-01-03  0.526889 -1.235301  0.370054  1.875714
# 2013-01-04 -0.806553  1.251323  1.635073  0.042678
# 2013-01-05  0.777844 -1.018387  0.005510  0.164077
# 2013-01-06  1.789882  0.732778 -0.935361 -0.737313

# %%
#给指定列赋相同值
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.012649 -0.258957  5
# 2013-01-02 -1.006992 -0.097120 -0.880813  5
# 2013-01-03  0.526889 -1.235301  0.370054  5
# 2013-01-04 -0.806553  1.251323  1.635073  5
# 2013-01-05  0.777844 -1.018387  0.005510  5
# 2013-01-06  1.789882  0.732778 -0.935361  5

# %%
#条件赋值
df[df > 0] = 8
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  8.000000 -0.258957  8
# 2013-01-02 -1.006992 -0.097120 -0.880813  8
# 2013-01-03  8.000000 -1.235301  8.000000  8
# 2013-01-04 -0.806553  8.000000  8.000000  8
# 2013-01-05  8.000000 -1.018387  8.000000  8
# 2013-01-06  8.000000  8.000000 -0.935361  8

# %%
#条件赋值:对B列中值为8的单元格赋值为7
df['B'][df['B'] == 8.] = 7
df
# Out:
# c:\program files\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    A         B         C  D
# 2013-01-01  0.000000  7.000000 -0.258957  8
# 2013-01-02 -1.006992 -0.097120 -0.880813  8
# 2013-01-03  8.000000 -1.235301  8.000000  8
# 2013-01-04 -0.806553  7.000000  8.000000  8
# 2013-01-05  8.000000 -1.018387  8.000000  8
# 2013-01-06  8.000000  7.000000 -0.935361  8

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.000000   -1.006992    8.000000   -0.806553    8.000000    8.000000
# B    7.000000   -0.097120   -1.235301    7.000000   -1.018387    7.000000
# C   -0.258957   -0.880813    8.000000    8.000000    8.000000   -0.935361
# D    8.000000    8.000000    8.000000    8.000000    8.000000    8.000000

# %%
df = pd.DataFrame(np.random.randn(4, 4), columns=['A', 'B', 'C', 'D'])
s = pd.DataFrame(np.random.randn(3, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  1.228559 -0.771879 -0.931396 -0.751252
# 1  1.249340  0.126053 -0.423793  0.945360
# 2 -2.469354 -0.581592 -1.447904  1.452097
# 3  1.220161  0.584340 -1.019782  0.047759

# %%
s
# Out:
#           A         B         C         D
# 0  0.556268  1.406479  0.738374 -1.021303
# 1  0.691891 -0.745961  0.823422 -0.708812
# 2 -0.067763 -0.874265 -0.156818 -2.093045

# %%
df1=df.append(s, ignore_index=True)  # 注意：df未变
df1
# Out:
#           A         B         C         D
# 0  1.228559 -0.771879 -0.931396 -0.751252
# 1  1.249340  0.126053 -0.423793  0.945360
# 2 -2.469354 -0.581592 -1.447904  1.452097
# 3  1.220161  0.584340 -1.019782  0.047759
# 4  0.556268  1.406479  0.738374 -1.021303
# 5  0.691891 -0.745961  0.823422 -0.708812
# 6 -0.067763 -0.874265 -0.156818 -2.093045

# %%
df = pd.DataFrame(np.random.randn(4, 4), columns=['A', 'B', 'C', 'D'])
df['E']=0
df
# Out:
#           A         B         C         D  E
# 0 -0.465042  1.060100  0.997618  0.272424  0
# 1 -0.166282 -0.066194 -1.657286 -1.875422  0
# 2  0.547335 -0.086239  0.706570 -0.250322  0
# 3 -0.565922 -0.013839 -2.199718  0.771609  0

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.386533 -0.228643  0.629050  0.106873
# 1 -0.875546 -0.877459 -0.980092 -0.966399
# 2  0.884672  0.527935  0.299250  0.593709
# 3 -1.214599 -0.456971 -0.998022 -0.160819
# 4  0.141649  1.729724  0.343527 -0.339506
# 5  0.670100  0.279980 -0.274790 -0.443627
# 6 -0.057905 -0.154342  0.697446  0.058333
# 7 -1.479587  0.211269 -0.015390 -2.506528

# %%
df.drop(1,axis=0, inplace=True)
df
# Out:
#           A         B         C         D
# 0  0.386533 -0.228643  0.629050  0.106873
# 2  0.884672  0.527935  0.299250  0.593709
# 3 -1.214599 -0.456971 -0.998022 -0.160819
# 4  0.141649  1.729724  0.343527 -0.339506
# 5  0.670100  0.279980 -0.274790 -0.443627
# 6 -0.057905 -0.154342  0.697446  0.058333
# 7 -1.479587  0.211269 -0.015390 -2.506528

# %%
df.drop(labels=range(3,5),axis=0, inplace=True)
df
# Out:
#           A         B         C         D
# 0  0.386533 -0.228643  0.629050  0.106873
# 2  0.884672  0.527935  0.299250  0.593709
# 5  0.670100  0.279980 -0.274790 -0.443627
# 6 -0.057905 -0.154342  0.697446  0.058333
# 7 -1.479587  0.211269 -0.015390 -2.506528

# %%
df.drop('B',axis=1, inplace=True)
df
# Out:
#           A         C         D
# 0  0.386533  0.629050  0.106873
# 2  0.884672  0.299250  0.593709
# 5  0.670100 -0.274790 -0.443627
# 6 -0.057905  0.697446  0.058333
# 7 -1.479587 -0.015390 -2.506528

# %%
df.rename(columns={'D':'E'},inplace=True)
df
# Out:
#           A         C         E
# 0  0.386533  0.629050  0.106873
# 2  0.884672  0.299250  0.593709
# 5  0.670100 -0.274790 -0.443627
# 6 -0.057905  0.697446  0.058333
# 7 -1.479587 -0.015390 -2.506528

# %%
df_new = df.reset_index(drop = True)
df_new
# Out:
#           A         C         E
# 0  0.386533  0.629050  0.106873
# 1  0.884672  0.299250  0.593709
# 2  0.670100 -0.274790 -0.443627
# 3 -0.057905  0.697446  0.058333
# 4 -1.479587 -0.015390 -2.506528

# %%
df_new = df.reset_index()
df_new
# Out:
#    index         A         C         E
# 0      0  0.386533  0.629050  0.106873
# 1      2  0.884672  0.299250  0.593709
# 2      5  0.670100 -0.274790 -0.443627
# 3      6 -0.057905  0.697446  0.058333
# 4      7 -1.479587 -0.015390 -2.506528

# %%
df_new.set_index('index', inplace = True)
df_new
# Out:
#               A         C         E
# index
# 0      0.386533  0.629050  0.106873
# 2      0.884672  0.299250  0.593709
# 5      0.670100 -0.274790 -0.443627
# 6     -0.057905  0.697446  0.058333
# 7     -1.479587 -0.015390 -2.506528

# %%
df1 = df.append(df[3:4])  
df1
# Out:
#           A         C         E
# 0  0.386533  0.629050  0.106873
# 2  0.884672  0.299250  0.593709
# 5  0.670100 -0.274790 -0.443627
# 6 -0.057905  0.697446  0.058333
# 7 -1.479587 -0.015390 -2.506528
# 6 -0.057905  0.697446  0.058333

# %%
df1.duplicated()
# Out:
# 0    False
# 2    False
# 5    False
# 6    False
# 7    False
# 6     True
# dtype: bool

# %%
df1.drop_duplicates(inplace = True)
df1
# Out:
#           A         C         E
# 0  0.386533  0.629050  0.106873
# 2  0.884672  0.299250  0.593709
# 5  0.670100 -0.274790 -0.443627
# 6 -0.057905  0.697446  0.058333
# 7 -1.479587 -0.015390 -2.506528

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#              A   C    E    E
# 2013-01-01 NaN NaN  1.0  1.0
# 2013-01-02 NaN NaN  1.0  1.0
# 2013-01-03 NaN NaN  NaN  NaN
# 2013-01-04 NaN NaN  NaN  NaN

# %%
m=df1.notnull().sum()  #统计非缺失值个数（逐行统计）
m
# Out:
# A    0
# C    0
# E    2
# E    2
# dtype: int64

# %%
df3=df1.dropna(how='any')   #删除所有含缺失值的行，注意：df1不变
df3
# Out:
# Empty DataFrame
# Columns: [A, C, E, E]
# Index: []

# %%
df3=df1.fillna(value=5) #将缺失值填充为5，注意：df1未改变。
df3
# Out:
#               A    C    E    E
# 2013-01-01  5.0  5.0  1.0  1.0
# 2013-01-02  5.0  5.0  1.0  1.0
# 2013-01-03  5.0  5.0  5.0  5.0
# 2013-01-04  5.0  5.0  5.0  5.0

# %%
df1.iloc[:,1:2].fillna(5,inplace=True) #将C列缺失值填充为5
df1
# Out:
# C:\Users\Steven Ray\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py:4465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#              A    C    E    E
# 2013-01-01 NaN  5.0  1.0  1.0
# 2013-01-02 NaN  5.0  1.0  1.0
# 2013-01-03 NaN  5.0  NaN  NaN
# 2013-01-04 NaN  5.0  NaN  NaN
