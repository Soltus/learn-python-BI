# %%
import pandas as pd
import numpy as np
detail = pd.read_csv('./data/meal_order_detail.csv', sep = ',',encoding = 'utf-8')
detail
# Out:
#        detail_id  order_id  dishes_id  logicprn_name  parent_class_name  \
# 0            753       137     609970            NaN                NaN
# 1            754       137     610047            NaN                NaN
# 2            755       137     609992            NaN                NaN
# 3            758       137     609945            NaN                NaN
# 4            759       137     610010            NaN                NaN
# ...          ...       ...        ...            ...                ...
# 10032       8242       910     610013            NaN                NaN
# 10033       8243       910     609957            NaN                NaN
# 10034       8244       910     609956            NaN                NaN
# 10035       8245       910     610019            NaN                NaN
# 10036       8246       910     609970            NaN                NaN
#
#              dishes_name  itemis_add  counts  amounts  cost place_order_time  \
# 0                  麻辣小龙虾           0       1       99   NaN   2016-8-3 14:01
# 1                西瓜胡萝卜沙拉           0       1       26   NaN   2016-8-3 14:01
# 2              番茄炖牛腩\r\n           0       1       35   NaN   2016-8-3 14:02
# 3        农夫山泉NFC果汁100%橙汁           0       1        6   NaN   2016-8-3 14:02
# 4                  白饭/小碗           0       4        1   NaN   2016-8-3 14:04
# ...                  ...         ...     ...      ...   ...              ...
# 10032              番茄炖秋葵           0       1       35   NaN  2016-8-27 20:40
# 10033  蒙古烤羊腿\r\n\r\n\r\n           0       1       48   NaN  2016-8-27 20:45
# 10034               孜然羊排           0       1       88   NaN  2016-8-27 20:47
# 10035                白斩鸡           0       1       88   NaN  2016-8-27 20:51
# 10036              麻辣小龙虾           0       1       99   NaN  2016-8-27 20:54
#
#        discount_amt  discount_reason  kick_back  add_inprice  add_info  \
# 0               NaN              NaN        NaN            0       NaN
# 1               NaN              NaN        NaN            0       NaN
# 2               NaN              NaN        NaN            0       NaN
# 3               NaN              NaN        NaN            0       NaN
# 4               NaN              NaN        NaN            0       NaN
# ...             ...              ...        ...          ...       ...
# 10032           NaN              NaN        NaN            0       NaN
# 10033           NaN              NaN        NaN            0       NaN
# 10034           NaN              NaN        NaN            0       NaN
# 10035           NaN              NaN        NaN            0       NaN
# 10036           NaN              NaN        NaN            0       NaN
#
#        bar_code      picture_file  emp_id
# 0           NaN  caipu/101006.jpg    1248
# 1           NaN  caipu/301001.jpg    1248
# 2           NaN  caipu/201002.jpg    1248
# 3           NaN  caipu/404001.jpg    1248
# 4           NaN  caipu/601004.jpg    1248
# ...         ...               ...     ...
# 10032       NaN  caipu/302002.jpg    1151
# 10033       NaN  caipu/202003.jpg    1151
# 10034       NaN  caipu/202002.jpg    1151
# 10035       NaN  caipu/204002.jpg    1151
# 10036       NaN  caipu/101006.jpg    1151
#
# [10037 rows x 19 columns]

# %%
detailPivot = pd.pivot_table(detail[['order_id','counts','amounts']], index = 'order_id')
detailPivot.head()
# Out:
#             amounts    counts
# order_id
# 137       32.333333  1.500000
# 162       68.800000  1.200000
# 163       36.400000  2.000000
# 165       52.944444  1.166667
# 166       48.200000  1.400000

# %%
detailPivot1 = pd.pivot_table(detail[['order_id','counts','amounts']],index = 'order_id',aggfunc = np.sum)
detailPivot1.head()
# Out:
#           amounts  counts
# order_id
# 137           194       9
# 162          1032      18
# 163           182      10
# 165           953      21
# 166           241       7

# %%
detailPivot2 = pd.pivot_table(detail[['order_id','dishes_name','counts','amounts']],
      index = ['order_id','dishes_name'],aggfunc = np.sum)
detailPivot2.head()
# Out:
#                           amounts  counts
# order_id dishes_name
# 137      农夫山泉NFC果汁100%橙汁        6       1
#          凉拌菠菜                  27       1
#          番茄炖牛腩\r\n             35       1
#          白饭/小碗                  1       4
#          西瓜胡萝卜沙拉               26       1

# %%
detailPivot2 = pd.pivot_table(detail[['order_id','dishes_name','counts','amounts']],
      index = 'order_id',columns = 'dishes_name',aggfunc = np.sum)
detailPivot2.iloc[:5,:4]
# Out:
#             amounts
# dishes_name  42度海之蓝  北冰洋汽水  38度剑南春  50度古井贡酒
# order_id
# 137             NaN     NaN     NaN     NaN
# 162             NaN     NaN     NaN     NaN
# 163             NaN     NaN     NaN     NaN
# 165             NaN     NaN    80.0     NaN
# 166             NaN     NaN     NaN     NaN

# %%
detailPivot4 = pd.pivot_table(detail[['order_id','dishes_name','counts','amounts']],
      index = 'order_id',values = 'counts', aggfunc = np.sum)
detailPivot4.head()
# Out:
#           counts
# order_id
# 137            9
# 162           18
# 163           10
# 165           21
# 166            7

# %%
detailPivot5 = pd.pivot_table(detail[['order_id','dishes_name','counts','amounts']],
      index = 'order_id',columns = 'dishes_name',aggfunc = np.sum,fill_value = 0)
detailPivot5.iloc[:5,:4]
# Out:
#             amounts
# dishes_name  42度海之蓝  北冰洋汽水  38度剑南春  50度古井贡酒
# order_id
# 137               0       0       0       0
# 162               0       0       0       0
# 163               0       0       0       0
# 165               0       0      80       0
# 166               0       0       0       0

# %%
detailPivot6 = pd.pivot_table(detail[['order_id','dishes_name','counts','amounts']],
      index = 'order_id',columns = 'dishes_name',aggfunc = np.sum,fill_value = 0,margins = True)
detailPivot6.iloc[:5,-4:]
# Out:
#             counts
# dishes_name 黄油曲奇饼干 黄花菜炒木耳 黑米恋上葡萄 All
# order_id
# 137              0      0      0   9
# 162              2      0      0  18
# 163              0      0      0  10
# 165              0      1      0  21
# 166              0      0      0   7

# %%
detailCross = pd.crosstab(index=detail['order_id'],columns=detail['dishes_name'],
      values = detail['counts'],aggfunc = np.sum)
detailCross.iloc[:5,:5]
# Out:
# dishes_name   42度海之蓝   北冰洋汽水   38度剑南春   50度古井贡酒  52度泸州老窖
# order_id
# 137              NaN      NaN      NaN      NaN       NaN
# 162              NaN      NaN      NaN      NaN       NaN
# 163              NaN      NaN      NaN      NaN       NaN
# 165              NaN      NaN      1.0      NaN       NaN
# 166              NaN      NaN      NaN      NaN       NaN
