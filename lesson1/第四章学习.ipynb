# %%
import matplotlib.pyplot as plt

# 声明字典
d = {'001':89,'002':78,'003':92,'126':48}

# 从字典中提取成绩数据
scores = list(d.values())

# 绘制直方图
plt.hist(scores)

# 添加标签
plt.title('Business Intelligence Scores')
plt.xlabel('Score')
plt.ylabel('number')

# 显示图形
plt.show()
